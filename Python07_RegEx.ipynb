# %%
import re
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

# %%
txt= "The rain in Spain"
x= re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
import re
txt= "The rain in Spain"
x= re.findall("Portugal", txt)
print(x)
# Out:
# []

# %%
import re
txt = "The rain in Spain"
x = re.search("\s", txt)
print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\user\AppData\Local\Temp\ipykernel_8600\4009967224.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.search("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\user\AppData\Local\Temp\ipykernel_8600\4124838735.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt)
print(x)
# Out:
# The9rain9in9Spain
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\user\AppData\Local\Temp\ipykernel_8600\848184127.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\user\AppData\Local\Temp\ipykernel_8600\2178968812.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt, 2)
# C:\Users\user\AppData\Local\Temp\ipykernel_8600\2178968812.py:3: DeprecationWarning: 'count' is passed as positional argument
#   x = re.sub("\s", "9", txt, 2)

# %%
import re
txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
# Out:
# (12, 17)

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.string)
# Out:
# The rain in Spain

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain

# %%
try:
 print(x)
except:
 print("An exception occurred")
# Out:
# An exception occurred

# %%
try:
 print(x)
except NameError:
 print("Variable x is not defined")
except:
 print("Something else went wrong")
# Out:
# Variable x is not defined

# %%
txt = f"The price is 49 dollars"
print(txt)
# Out:
# The price is 49 dollars

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
txt = f"The price is {95:.2f} dollars"
print(txt)
# Out:
# The price is 95.00 dollars

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %%
price = 59
tax = 0.25
txt = f"The price is {price + (price * tax)} dollars"
print(txt)
# Out:
# The price is 73.75 dollars

# %%
price = 49
txt = f"It is very {'Expensive' if price>50 else 'Cheap'}"
print(txt)
# Out:
# It is very Cheap

# %%
fruit = "apples"
txt = f"I love {fruit.upper()}"
print(txt)
# Out:
# I love APPLES

# %%
def myconverter(x):
 return x * 0.3048
txt = f"The plane is flying at a {myconverter(30000)} meter altitude"
print(txt)
# Out:
# The plane is flying at a 9144.0 meter altitude

# %%
price = 59000
txt = f"The price is {price:,} dollars"
print(txt)
# Out:
# The price is 59,000 dollars

# %%
price = 49
txt = "The price is {} dollars"
print(txt.format(price))
# Out:
# The price is 49 dollars

# %%
txt = "The price is {:.2f} dollars"
price = 49
print(txt.format(price))
# Out:
# The price is 49.00 dollars

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {} pieces of item number {} for {:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
result = None
if result is None:
    print("No result yet")
else:
    
    print("Result is ready")
# Out:
# No result yet

# %%
result = None
if result is not None:
    print("Result is ready")
else:
    print("No result yet")
# Out:
# No result yet

# %%
name = input("Enter your name:")
print(f"Hello {name}")
# Out:
# Hello rladudco

# %%
name = input("Enter your name:")
print(f"Hello {name}")
fav1 = input("What is your favorite animal:")
fav2 = input("What is your favorite color:")
fav3 = input("What is your favorite number:")
print(f"Do you want a {fav2} {fav1} with {fav3} legs?")
# Out:
# Hello  영채
# Do you want a 하얀 강아지 with 4 legs?

# %%
x = input("Enter a number:")
#find the square root of the number:
import math
y = math.sqrt(float(x))
print(f"The square root of {x} is {y}")
# Out:
# The square root of 84 is 9.16515138991168
